# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %%
x = np.linspace(0, 10, 100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
fig = plt.figure()
plt.plot(x, np.sin(x), '-', 'r')
plt.plot(x, np.cos(x), '--', 'y')
# Out:
# [<matplotlib.lines.Line2D at 0x21325c79280>,
#  <matplotlib.lines.Line2D at 0x21325c796a0>]

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is EE5D-86FB
#
#  Directory of C:\Users\Arindam
#
# 09/16/2020  08:46 AM    <DIR>          .
# 09/16/2020  08:46 AM    <DIR>          ..
# 09/03/2019  03:00 AM    <DIR>          .anaconda
# 09/14/2020  09:09 PM    <DIR>          .conda
# 09/14/2020  08:52 PM                43 .condarc
# 01/16/2020  04:00 AM    <DIR>          .config
# 04/15/2020  08:03 AM               126 .defaults-0.1.0.ini
# 09/08/2020  05:58 AM    <DIR>          .idlerc
# 09/16/2020  07:06 AM    <DIR>          .ipynb_checkpoints
# 09/07/2019  05:46 AM    <DIR>          .ipython
# 04/22/2020  07:45 AM    <DIR>          .jupyter
# 04/22/2020  08:10 AM    <DIR>          .keras
# 01/16/2020  03:59 AM    <DIR>          .matplotlib
# 09/09/2020  01:42 PM    <DIR>          .spyder-py3
# 08/23/2020  10:57 AM    <DIR>          .VirtualBox
# 12/05/2019  05:57 AM             2,436 50_Startups.csv
# 09/08/2020  06:44 AM    <DIR>          Anaconda3
# 06/19/2016  10:32 PM    <DIR>          Contacts
# 08/30/2020  10:38 AM    <DIR>          Desktop
# 09/13/2020  10:27 AM    <DIR>          Documents
# 09/16/2020  07:53 AM    <DIR>          Downloads
# 06/19/2016  10:32 PM    <DIR>          Favorites
# 09/16/2020  04:19 AM            17,269 Interactive Notebook.ipynb
# 09/14/2020  02:44 AM            47,378 Libraries.ipynb
# 06/19/2016  10:32 PM    <DIR>          Links
# 07/21/2020  03:45 AM            37,601 Loan Prediction.ipynb
# 07/25/2020  12:12 AM           126,689 Loan_prediction.ipynb
# 01/17/2020  05:10 AM             5,965 Logistic Regression Analysis_V2.py
# 01/17/2020  03:24 AM             3,825 multiple_linear_regression.py
# 08/30/2020  02:06 PM    <DIR>          Music
# 05/06/2020  08:47 AM            73,384 Neural network.ipynb
# 04/15/2020  08:03 AM    <DIR>          nlp
# 09/09/2020  03:28 AM    <DIR>          OneDrive
# 10/14/2019  11:32 AM    <DIR>          Pictures
# 01/16/2020  06:29 AM    <DIR>          Python
# 04/15/2020  07:28 AM    <DIR>          Python_Arindam
# 01/20/2020  12:40 PM           754,526 Python_Arindam.ipynb
# 06/19/2016  10:32 PM    <DIR>          Saved Games
# 09/04/2020  06:40 AM    <DIR>          seaborn-data
# 09/08/2020  07:20 AM                72 Untitled46.ipynb
# 09/08/2020  07:23 AM                72 Untitled47.ipynb
# 09/08/2020  07:31 AM               886 Untitled48.ipynb
# 09/08/2020  07:34 AM               573 Untitled49.ipynb
# 01/20/2020  06:20 AM                72 Untitled5.ipynb
# 09/08/2020  07:35 AM                72 Untitled50.ipynb
# 09/09/2020  04:01 AM             3,619 Untitled51.ipynb
# 09/16/2020  03:57 AM           107,278 Untitled52.ipynb
# 09/16/2020  03:51 AM            57,571 Untitled53.ipynb
# 09/16/2020  08:46 AM            57,620 Untitled54.ipynb
# 01/20/2020  06:20 AM                72 Untitled6.ipynb
# 01/20/2020  06:20 AM                72 Untitled7.ipynb
# 01/20/2020  06:59 AM           741,387 Untitled8.ipynb
# 01/20/2020  12:41 PM             3,126 Untitled9.ipynb
# 09/14/2020  12:53 AM    <DIR>          Videos
# 07/27/2020  01:37 AM    <DIR>          VirtualBox VMs
#               68 File(s)      3,040,245 bytes
#               32 Dir(s)   9,464,864,768 bytes free

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %%
fig = plt.figure()
plt.plot(x, np.sin(x), 'X', 'r')
plt.plot(x, np.cos(x), 'XX', 'y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-4ba8d55802e2> in <module>
#       1 fig = plt.figure()
#       2 plt.plot(x, np.sin(x), 'X', 'r')
# ----> 3 plt.plot(x, np.cos(x), 'XX', 'y')
#
# ~\Anaconda3\Anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# ~\Anaconda3\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ~\Anaconda3\Anaconda\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~\Anaconda3\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     310     def _plot_args(self, tup, kwargs):
#     311         if len(tup) > 1 and isinstance(tup[-1], str):
# --> 312             linestyle, marker, color = _process_plot_format(tup[-1])
#     313             tup = tup[:-1]
#     314         elif len(tup) == 3:
#
# ~\Anaconda3\Anaconda\lib\site-packages\matplotlib\axes\_base.py in _process_plot_format(fmt)
#      87         elif c in mlines.lineMarkers:
#      88             if marker is not None:
# ---> 89                 raise ValueError(
#      90                     'Illegal format string "%s"; two marker symbols' % fmt)
#      91             marker = c
#
# ValueError: Illegal format string "XX"; two marker symbols

# %%
import matplotlib.pyplot as plt
import seaborn as sns


iris=sns.load_dataset("iris")

# %%
sns.scatterplot(x="species",y="petal_length",data=iris)
