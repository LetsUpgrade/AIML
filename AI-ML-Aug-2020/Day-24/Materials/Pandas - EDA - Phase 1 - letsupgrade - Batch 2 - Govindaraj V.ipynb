# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1d - Series

# %%
s=pd.Series()
print(s)
# Out:
# Series([], dtype: float64)
# <ipython-input-2-f8daae661c20>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s=pd.Series()

# %%
df=[1,12,3,4,5]
s1=pd.Series(df)
print(s1)
# Out:
# 0     1
# 1    12
# 2     3
# 3     4
# 4     5
# dtype: int64

# %%
df1=[1,12,3,4,5,'a']
s2=pd.Series(df1)
print(s2)
# Out:
# 0     1
# 1    12
# 2     3
# 3     4
# 4     5
# 5     a
# dtype: object

# %%
s2.shape
# Out:
# (6,)

# %%
s2.shape[0]
# Out:
# 6

# %%
s2.shape[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-e32b9d9b0ed4> in <module>
# ----> 1 s2.shape[1]
#
# IndexError: tuple index out of range

# %%
s
# Out:
# Series([], dtype: float64)

# %%
s1
# Out:
# 0     1
# 1    12
# 2     3
# 3     4
# 4     5
# dtype: int64

# %%
df1
# Out:
# [1, 12, 3, 4, 5, 'a']

# %%
s3=pd.Series(df1,index=[12,13,14,15,16,17])
print(s3)
# Out:
# 12     1
# 13    12
# 14     3
# 15     4
# 16     5
# 17     a
# dtype: object

# %%
s3[12]
# Out:
# 1

# %%
d={'a':'hello','b':'welcome','c': 'to python'}

# %%
dd=pd.Series(d)
print(dd)
# Out:
# a        hello
# b      welcome
# c    to python
# dtype: object

# %%
dd=pd.Series(d,index=['a','d','c','f','b'])
print(dd)
# Out:
# a        hello
# d          NaN
# c    to python
# f          NaN
# b      welcome
# dtype: object

# %% [markdown]
# # 2d- DataFrame
#
# -- all the columns are of different types
#
# -- size is mutable
#
# -- Lebeled Axes
#
# -- can perform all the arithmentic operation

# %%
data=pd.read_csv('C:/Users/guruc/Documents/AIML/dataset/diabetes_with_names.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72           35.0        0  33.6
# 1          NaN       85             66           29.0        0  26.6
# 2          8.0      183             64            0.0        0   NaN
# 3          1.0       89             66           23.0       94  28.1
# 4          0.0      137             40           35.0      168  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351   NaN        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763         10.0      101             76           48.0      180  32.9
# 764          2.0      122             70           27.0        0  36.8
# 765          5.0      121             72           23.0      112  26.2
# 766          1.0      126             60            0.0        0  30.1
# 767          1.0       93             70           31.0        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 763                     0.171  63.0        0
# 764                     0.340  27.0        0
# 765                     0.245  30.0        0
# 766                     0.349  47.0        1
# 767                     0.315  23.0        0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               766 non-null    float64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             767 non-null    float64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       767 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       767 non-null    float64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(5), int64(4)
# memory usage: 54.1 KB

# %%
data.dtypes
# Out:
# Pregnancies                 float64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness               float64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                         float64
# Outcome                       int64
# dtype: object

# %%
data.shape
# Out:
# (768, 9)

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data['Age'].nunique()
# Out:
# 52

# %%
data['Outcome'].nunique()
# Out:
# 2

# %%
data['Age'].unique()
# Out:
# array([50., nan, 32., 21., 33., 30., 26., 29., 53., 54., 34., 57., 59.,
#        51., 31., 27., 41., 43., 22., 38., 60., 28., 45., 35., 46., 56.,
#        37., 48., 40., 25., 24., 58., 42., 44., 39., 36., 23., 61., 69.,
#        62., 55., 65., 47., 52., 66., 49., 63., 67., 72., 81., 64., 70.,
#        68.])

# %%
data['Outcome'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data.dtypes
# Out:
# Pregnancies                 float64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness               float64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                         float64
# Outcome                       int64
# dtype: object

# %%
data['Outcome']=data['Outcome'].astype('category')

# %%
data.dtypes
# Out:
# Pregnancies                  float64
# Glucose                        int64
# BloodPressure                  int64
# SkinThickness                float64
# Insulin                        int64
# BMI                          float64
# DiabetesPedigreeFunction     float64
# Age                          float64
# Outcome                     category
# dtype: object

# %%
data.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               766.0    3.849869    3.372270   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             767.0   20.517601   15.954059   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       767.0   32.003911    7.883043   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       767.0   33.243807   11.767627  21.000  24.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00

# %%
data.hist(figsize=(12,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000245722ADA30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002457298BEE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000245729C6370>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000245729F17F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024572A21C40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024572A4F130>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024572A5B100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024572A855B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024572ADDD30>]],
#       dtype=object)

# %% [markdown]
# Missing Values indentifying

# %%
data.isna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1           True    False          False          False    False  False
# 2          False    False          False          False    False   True
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False   True    False
# 2                       False  False    False
# 3                       False  False    False
# 4                       False  False    False
# ..                        ...    ...      ...
# 763                     False  False    False
# 764                     False  False    False
# 765                     False  False    False
# 766                     False  False    False
# 767                     False  False    False
#
# [768 rows x 9 columns]

# %%
data.isna().sum()
# Out:
# Pregnancies                 2
# Glucose                     0
# BloodPressure               0
# SkinThickness               1
# Insulin                     0
# BMI                         1
# DiabetesPedigreeFunction    0
# Age                         1
# Outcome                     0
# dtype: int64

# %%
data.notna().sum()
# Out:
# Pregnancies                 766
# Glucose                     768
# BloodPressure               768
# SkinThickness               767
# Insulin                     768
# BMI                         767
# DiabetesPedigreeFunction    768
# Age                         767
# Outcome                     768
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Pregnancies                 766
# Glucose                     768
# BloodPressure               768
# SkinThickness               767
# Insulin                     768
# BMI                         767
# DiabetesPedigreeFunction    768
# Age                         767
# Outcome                     768
# dtype: int64

# %%
data1=data.dropna()

# %%
data1.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data1.shape
# Out:
# (764, 9)

# %%
data.shape
# Out:
# (768, 9)

# %%
data.isna().sum()
# Out:
# Pregnancies                 2
# Glucose                     0
# BloodPressure               0
# SkinThickness               1
# Insulin                     0
# BMI                         1
# DiabetesPedigreeFunction    0
# Age                         1
# Outcome                     0
# dtype: int64

# %%
data['Outcome']=data['Outcome'].astype('int64')

# %%
data.dtypes
# Out:
# Pregnancies                 float64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness               float64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                         float64
# Outcome                       int64
# dtype: object

# %%
data.isna().sum()
# Out:
# Pregnancies                 2
# Glucose                     0
# BloodPressure               0
# SkinThickness               1
# Insulin                     0
# BMI                         1
# DiabetesPedigreeFunction    0
# Age                         1
# Outcome                     0
# dtype: int64

# %%
data.fillna(100)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0            6.0      148             72           35.0        0   33.6
# 1          100.0       85             66           29.0        0   26.6
# 2            8.0      183             64            0.0        0  100.0
# 3            1.0       89             66           23.0       94   28.1
# 4            0.0      137             40           35.0      168   43.1
# ..           ...      ...            ...            ...      ...    ...
# 763         10.0      101             76           48.0      180   32.9
# 764          2.0      122             70           27.0        0   36.8
# 765          5.0      121             72           23.0      112   26.2
# 766          1.0      126             60            0.0        0   30.1
# 767          1.0       93             70           31.0        0   30.4
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       0.627   50.0        1
# 1                       0.351  100.0        0
# 2                       0.672   32.0        1
# 3                       0.167   21.0        0
# 4                       2.288   33.0        1
# ..                        ...    ...      ...
# 763                     0.171   63.0        0
# 764                     0.340   27.0        0
# 765                     0.245   30.0        0
# 766                     0.349   47.0        1
# 767                     0.315   23.0        0
#
# [768 rows x 9 columns]

# %%
data.fillna(data.mean()).head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0     6.000000      148             72           35.0        0  33.600000
# 1     3.849869       85             66           29.0        0  26.600000
# 2     8.000000      183             64            0.0        0  32.003911
# 3     1.000000       89             66           23.0       94  28.100000
# 4     0.000000      137             40           35.0      168  43.100000
#
#    DiabetesPedigreeFunction        Age  Outcome
# 0                     0.627  50.000000        1
# 1                     0.351  33.243807        0
# 2                     0.672  32.000000        1
# 3                     0.167  21.000000        0
# 4                     2.288  33.000000        1

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72           35.0        0  33.6
# 1          NaN       85             66           29.0        0  26.6
# 2          8.0      183             64            0.0        0   NaN
# 3          1.0       89             66           23.0       94  28.1
# 4          0.0      137             40           35.0      168  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351   NaN        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1

# %%
data2=data.fillna(method='pad').head()

# %%
# %matplotlib inline

# %%
data2.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.fillna(method='bfill').head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72           35.0        0  33.6
# 1          8.0       85             66           29.0        0  26.6
# 2          8.0      183             64            0.0        0  28.1
# 3          1.0       89             66           23.0       94  28.1
# 4          0.0      137             40           35.0      168  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351  32.0        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1

# %%
data.fillna(method='ffill').head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0      148             72           35.0        0  33.6
# 1          6.0       85             66           29.0        0  26.6
# 2          8.0      183             64            0.0        0  26.6
# 3          1.0       89             66           23.0       94  28.1
# 4          0.0      137             40           35.0      168  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0        1
# 1                     0.351  50.0        0
# 2                     0.672  32.0        1
# 3                     0.167  21.0        0
# 4                     2.288  33.0        1

# %%
data.hist(figsize=(12,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024572FBD130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024572FF7580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000245731D2970>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000245731FFDC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024573239250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000245732655E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000245732656D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024573291B80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000245732EFA00>]],
#       dtype=object)

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128101       0.140944      -0.082919
# Glucose                      0.128101  1.000000       0.152590       0.057429
# BloodPressure                0.140944  0.152590       1.000000       0.206858
# SkinThickness               -0.082919  0.057429       0.206858       1.000000
# Insulin                     -0.074336  0.331357       0.088933       0.437974
# BMI                          0.018711  0.224599       0.281662       0.392153
# DiabetesPedigreeFunction    -0.034178  0.137337       0.041265       0.184821
# Age                          0.544352  0.263458       0.239498      -0.113505
# Outcome                      0.222000  0.466581       0.065068       0.073265
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.074336  0.018711                 -0.034178
# Glucose                   0.331357  0.224599                  0.137337
# BloodPressure             0.088933  0.281662                  0.041265
# SkinThickness             0.437974  0.392153                  0.184821
# Insulin                   1.000000  0.197080                  0.185071
# BMI                       0.197080  1.000000                  0.141662
# DiabetesPedigreeFunction  0.185071  0.141662                  1.000000
# Age                      -0.042349  0.035960                  0.033474
# Outcome                   0.130548  0.295253                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544352  0.222000
# Glucose                   0.263458  0.466581
# BloodPressure             0.239498  0.065068
# SkinThickness            -0.113505  0.073265
# Insulin                  -0.042349  0.130548
# BMI                       0.035960  0.295253
# DiabetesPedigreeFunction  0.033474  0.173844
# Age                       1.000000  0.238263
# Outcome                   0.238263  1.000000

# %%
sns.heatmap(data.corr(),annot=True,vmin=-1,vmax=+1)

# %%
sns.pairplot(data[['Age','BMI','Insulin']])

# %%
df=data.iloc[:,5:]

# %%
df.head(1)
# Out:
#     BMI  DiabetesPedigreeFunction   Age  Outcome
# 0  33.6                     0.627  50.0        1

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Outcome')

# %%
plt.scatter(data.Age,data.Insulin)

# %%
plt.scatter(data.Pregnancies,data.BloodPressure)

# %%
sns.barplot(x='Outcome',y='Insulin',data=data)

# %%
sns.barplot(x='Age',y='Insulin',data=data,hue='Outcome')

# %%
sns.lmplot(x='Age',y='Insulin',data=data,hue='Outcome')
