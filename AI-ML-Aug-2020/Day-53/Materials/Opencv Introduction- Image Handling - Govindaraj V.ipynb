# %%
import cv2
import numpy as np

# %%
img=cv2.imread('C:/Users/guruc/Documents/AIML/dataset/nature.jpg',-1)
cv2.imshow('Nature',img)
cv2.waitKey(0)
#cv2.destroyAllWindows()
cv2.destroyWindow('Nature')

# %% [markdown]
# # Write an Image

# %%
cv2.imwrite('Nature_write.jpg',img)
# Out:
# True

# %%
img=cv2.imread('C:/Users/guruc/Documents/AIML/dataset/nature.jpg',-1)
cv2.imshow('Nature',img)
k=cv2.waitKey(0)
if k==30:
    cv2.destroyAllWindows()
elif k==ord('s'):
    cv2.imwrite('Nature_one.jpg',img)
    cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt
img=cv2.imread('C:/Users/guruc/Documents/AIML/dataset/nature.jpg',0)
plt.imshow(img,cmap='gray',interpolation='bicubic')
plt.xticks([]),plt.yticks([])
plt.show()
