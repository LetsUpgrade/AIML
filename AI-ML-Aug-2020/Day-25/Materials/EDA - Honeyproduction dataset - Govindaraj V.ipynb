# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('honeyproduction.csv')

# %%
data
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
data.dtypespes
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
data.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %%
data.head(1)
# Out:
#   state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 0    AL  16000.0           71  1136000.0  159000.0        0.72   818000.0
#
#    year
# 0  1998

# %% [markdown]
# # How many states are included in the dataset?

# %%
data['state'].nunique()
# Out:
# 44

# %% [markdown]
# # Which are the states that are included in this dataset?

# %%
data['state'].unique()
# Out:
# array(['AL', 'AZ', 'AR', 'CA', 'CO', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN',
#        'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MI', 'MN', 'MS', 'MO', 'MT',
#        'NE', 'NV', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA',
#        'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY', 'SC'],
#       dtype=object)

# %% [markdown]
# # Calculate the average production for each state across all years?

# %%
data.head(1)
# Out:
#   state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 0    AL  16000.0           71  1136000.0  159000.0        0.72   818000.0
#
#    year
# 0  1998

# %%
data[['state','totalprod']].groupby('state').mean().round().head()
# Out:
#         totalprod
# state
# AL       825467.0
# AR      2810400.0
# AZ      2032267.0
# CA     23169000.0
# CO      1750600.0

# %% [markdown]
# # How many years data is provided in the dataset? and what is the starting & ending year?

# %%
data['year'].nunique()
# Out:
# 15

# %%
data['year'].min()
# Out:
# 1998

# %%
data['year'].max()
# Out:
# 2012

# %% [markdown]
# # which state has been highest valume in production and in which year?

# %%
data[data['totalprod']==data['totalprod'].max()]
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 532    ND  510000.0           91  46410000.0  12995000.0         1.5
#
#       prodvalue  year
# 532  69615000.0  2010

# %% [markdown]
# # What is the average yield per colony ,for each year?

# %%
data[['year','yieldpercol']].groupby('year').mean().round().head()
# Out:
#       yieldpercol
# year
# 1998         70.0
# 1999         65.0
# 2000         68.0
# 2001         65.0
# 2002         67.0

# %%
sns.heatmap(data.corr(),annot=True,vmin=-1,vmax=1)

# %%
sns.pointplot(data['year'],data['totalprod'])

# %%
g=sns.FacetGrid(data,col='state',col_wrap=6,size=2)
g=g.map(plt.plot,'year','totalprod',marker='.')
# Out:
# C:\Users\guruc\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(x='numcol',y='prodvalue',data=data,hue='state')

# %%
sns.lmplot(x='numcol',y='prodvalue',data=data,hue='year')

# %%
fig,ax=plt.subplots(figsize=(20,10))
sns.boxplot('year','totalprod',data=data)

# %%
sns.pairplot(data)

# %%
data.head(1)
# Out:
#   state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 0    AL  16000.0           71  1136000.0  159000.0        0.72   818000.0
#
#    year
# 0  1998

# %%
sns.boxenplot(data['stocks'])
