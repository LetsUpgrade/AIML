# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# for market basket analysis
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
os.chdir('F:\Lets Upgrade\Online Retail.xlsx')

df = pd.read_csv('Online Retail.csv',encoding = 'unicode_escape')

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# #
# First observations:

# %%
#shape of dataset:
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# # Checking the missing values in our data:

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# #
# Number of unique values in each variable:

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %% [markdown]
# # Data pre-processing
#
# Data cleaning

# %% [markdown]
# # In our data there are some invoices that are ‘credits’ rather of ‘debits’ so we want to remove them. They are indentified with “C” in the InvoiceNo field. We can see an example of these types of invoices with the following:

# %%
df[df['Quantity']<0].head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#          InvoiceDate  UnitPrice  CustomerID         Country
# 141   12/1/2010 9:41      27.50     14527.0  United Kingdom
# 154   12/1/2010 9:49       4.65     15311.0  United Kingdom
# 235  12/1/2010 10:24       1.65     17548.0  United Kingdom
# 236  12/1/2010 10:24       0.29     17548.0  United Kingdom
# 237  12/1/2010 10:24       0.29     17548.0  United Kingdom

# %% [markdown]
# We remove these rows:

# %%
df['InvoiceNo'] = df['InvoiceNo'].astype('str')

# %%
df = df[~df['InvoiceNo'].str.contains('C',na=False)]

# %%
df['InvoiceNo']
# Out:
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
#            ...
# 541904    581587
# 541905    581587
# 541906    581587
# 541907    581587
# 541908    581587
# Name: InvoiceNo, Length: 532621, dtype: object

# %% [markdown]
# #
# We also fill the missing values in CostumerID and Description:

# %%
df["CustomerID"] = df["CustomerID"].fillna('00000')
df["Description"] = df["Description"].fillna("Unkown")

# %% [markdown]
# # Feature engneering

# %% [markdown]
# We add column with an year, month and hour of each transaction:

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], errors='coerce')
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month
df['Hour'] = df['InvoiceDate'].dt.hour

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Year  Month  Hour
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom  2010     12     8
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom  2010     12     8
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom  2010     12     8
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom  2010     12     8
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom  2010     12     8

# %%
df['Month_year'] = pd.to_datetime(df['InvoiceDate']).dt.to_period('M')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Year  Month  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom  2010     12
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom  2010     12
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom  2010     12
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom  2010     12
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom  2010     12
#
#    Hour Month_year
# 0     8    2010-12
# 1     8    2010-12
# 2     8    2010-12
# 3     8    2010-12
# 4     8    2010-12

# %% [markdown]
# We count the income (revenues):
#
# We assigns the product of quantity and price to the Income column and we use round function to rounding the two decimal places. We receive revenues for every product.

# %%
df['Income'] = round(df['Quantity'] * df['UnitPrice'],2)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Year  Month  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom  2010     12
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom  2010     12
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom  2010     12
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom  2010     12
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom  2010     12
#
#    Hour Month_year  Income
# 0     8    2010-12   15.30
# 1     8    2010-12   20.34
# 2     8    2010-12   22.00
# 3     8    2010-12   20.34
# 4     8    2010-12   20.34

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# Summary statistic:

# %%
df.describe()
# Out:
#             Quantity      UnitPrice           Year          Month  \
# count  532621.000000  532621.000000  532621.000000  532621.000000
# mean       10.239972       3.847621    2010.921608       7.557864
# std       159.593551      41.758023       0.268787       3.508729
# min     -9600.000000  -11062.060000    2010.000000       1.000000
# 25%         1.000000       1.250000    2011.000000       5.000000
# 50%         3.000000       2.080000    2011.000000       8.000000
# 75%        10.000000       4.130000    2011.000000      11.000000
# max     80995.000000   13541.330000    2011.000000      12.000000
#
#                 Hour         Income
# count  532621.000000  532621.000000
# mean       13.077451      19.985244
# std         2.438535     270.574241
# min         6.000000  -11062.060000
# 25%        11.000000       3.750000
# 50%        13.000000       9.900000
# 75%        15.000000      17.700000
# max        20.000000  168469.600000

# %% [markdown]
# # Exploring the variables
#
# Lets check the values in other columns:

# %% [markdown]
# Quantity:

# %%
df[df['Quantity']>100].head()
# Out:
#     InvoiceNo StockCode                      Description  Quantity  \
# 96     536378     21212  PACK OF 72 RETROSPOT CAKE CASES       120
# 178    536387     79321                    CHILLI LIGHTS       192
# 179    536387     22780   LIGHT GARLAND BUTTERFILES PINK       192
# 180    536387     22779       WOODEN OWLS LIGHT GARLAND        192
# 181    536387     22466    FAIRY TALE COTTAGE NIGHTLIGHT       432
#
#             InvoiceDate  UnitPrice CustomerID         Country  Year  Month  \
# 96  2010-12-01 09:37:00       0.42      14688  United Kingdom  2010     12
# 178 2010-12-01 09:58:00       3.82      16029  United Kingdom  2010     12
# 179 2010-12-01 09:58:00       3.37      16029  United Kingdom  2010     12
# 180 2010-12-01 09:58:00       3.37      16029  United Kingdom  2010     12
# 181 2010-12-01 09:58:00       1.45      16029  United Kingdom  2010     12
#
#      Hour Month_year  Income
# 96      9    2010-12   50.40
# 178     9    2010-12  733.44
# 179     9    2010-12  647.04
# 180     9    2010-12  647.04
# 181     9    2010-12  626.40

# %% [markdown]
# #
# StockCode
#
# Numbers of unique products:

# %%
products = df['StockCode'].nunique()
print(products)
# Out:
# 4059

# %% [markdown]
# # Number of unique products ordered by customers:

# %%
products_group = df[['CustomerID', 'StockCode']].groupby('CustomerID').count().sort_values('StockCode', axis=0, ascending=False)
products_group.head(20)
# Out:
#             StockCode
# CustomerID
# 00000          134697
# 17841.0          7847
# 14911.0          5677
# 14096.0          5111
# 12748.0          4596
# 14606.0          2700
# 15311.0          2379
# 14646.0          2080
# 13089.0          1818
# 13263.0          1677
# 14298.0          1637
# 15039.0          1502
# 14156.0          1400
# 18118.0          1279
# 14159.0          1204
# 14796.0          1141
# 16033.0          1137
# 15005.0          1119
# 14056.0          1106
# 14769.0          1090

# %% [markdown]
# # Country
#
# List of unique countries

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Bahrain', 'Israel', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df[df['Country']=='Poland'].head()
# Out:
#      InvoiceNo StockCode                         Description  Quantity  \
# 6608    536971     21733    RED HANGING HEART T-LIGHT HOLDER        32
# 6609    536971     21232      STRAWBERRY CERAMIC TRINKET BOX        24
# 6610    536971     37446  MINI CAKE STAND WITH HANGING CAKES         8
# 6611    536971     37448     CERAMIC CAKE DESIGN SPOTTED MUG        24
# 6612    536971     21700         BIG DOUGHNUT FRIDGE MAGNETS        24
#
#              InvoiceDate  UnitPrice CustomerID Country  Year  Month  Hour  \
# 6608 2010-12-03 13:40:00       2.55      12779  Poland  2010     12    13
# 6609 2010-12-03 13:40:00       1.25      12779  Poland  2010     12    13
# 6610 2010-12-03 13:40:00       1.45      12779  Poland  2010     12    13
# 6611 2010-12-03 13:40:00       1.49      12779  Poland  2010     12    13
# 6612 2010-12-03 13:40:00       0.85      12779  Poland  2010     12    13
#
#      Month_year  Income
# 6608    2010-12   81.60
# 6609    2010-12   30.00
# 6610    2010-12   11.60
# 6611    2010-12   35.76
# 6612    2010-12   20.40

# %% [markdown]
# #
# InvoiceNo
#
# Number of unique orders:

# %%
df['InvoiceNo'].nunique()
# Out:
# 22064

# %% [markdown]
# # Number of unique orders by country:

# %%
country_group = df[['Country', 'InvoiceNo']].groupby('Country').count().sort_values('InvoiceNo', axis=0, ascending=False)
country_group
# Out:
#                       InvoiceNo
# Country
# United Kingdom           487622
# Germany                    9042
# France                     8408
# EIRE                       7894
# Spain                      2485
# Netherlands                2363
# Belgium                    2031
# Switzerland                1967
# Portugal                   1501
# Australia                  1185
# Norway                     1072
# Italy                       758
# Channel Islands             748
# Finland                     685
# Cyprus                      614
# Sweden                      451
# Unspecified                 446
# Austria                     398
# Denmark                     380
# Poland                      330
# Japan                       321
# Israel                      295
# Hong Kong                   284
# Singapore                   222
# Iceland                     182
# USA                         179
# Canada                      151
# Greece                      145
# Malta                       112
# United Arab Emirates         68
# European Community           60
# RSA                          58
# Lebanon                      45
# Lithuania                    35
# Brazil                       32
# Czech Republic               25
# Bahrain                      18
# Saudi Arabia                  9

# %% [markdown]
# #
# Description
#
# Descriptions of products:

# %%
df['Description'].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
df['Description'].value_counts().head(10)
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2327
# JUMBO BAG RED RETROSPOT               2115
# REGENCY CAKESTAND 3 TIER              2019
# PARTY BUNTING                         1707
# LUNCH BAG RED RETROSPOT               1594
# ASSORTED COLOUR BIRD ORNAMENT         1489
# Unkown                                1454
# SET OF 3 CAKE TINS PANTRY DESIGN      1399
# PACK OF 72 RETROSPOT CAKE CASES       1370
# LUNCH BAG  BLACK SKULL.               1328
# Name: Description, dtype: int64

# %%
df[df['Description']=='WHITE HANGING HEART T-LIGHT HOLDER'].head()
# Out:
#     InvoiceNo StockCode                         Description  Quantity  \
# 0      536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 49     536373    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 66     536375    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 220    536390    85123A  WHITE HANGING HEART T-LIGHT HOLDER        64
# 262    536394    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
#
#             InvoiceDate  UnitPrice CustomerID         Country  Year  Month  \
# 0   2010-12-01 08:26:00       2.55      17850  United Kingdom  2010     12
# 49  2010-12-01 09:02:00       2.55      17850  United Kingdom  2010     12
# 66  2010-12-01 09:32:00       2.55      17850  United Kingdom  2010     12
# 220 2010-12-01 10:19:00       2.55      17511  United Kingdom  2010     12
# 262 2010-12-01 10:39:00       2.55      13408  United Kingdom  2010     12
#
#      Hour Month_year  Income
# 0       8    2010-12    15.3
# 49      9    2010-12    15.3
# 66      9    2010-12    15.3
# 220    10    2010-12   163.2
# 262    10    2010-12    81.6

# %%
desc = df['Description'].value_counts().head(20)
desc
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2327
# JUMBO BAG RED RETROSPOT               2115
# REGENCY CAKESTAND 3 TIER              2019
# PARTY BUNTING                         1707
# LUNCH BAG RED RETROSPOT               1594
# ASSORTED COLOUR BIRD ORNAMENT         1489
# Unkown                                1454
# SET OF 3 CAKE TINS PANTRY DESIGN      1399
# PACK OF 72 RETROSPOT CAKE CASES       1370
# LUNCH BAG  BLACK SKULL.               1328
# NATURAL SLATE HEART CHALKBOARD        1263
# JUMBO BAG PINK POLKADOT               1238
# HEART OF WICKER SMALL                 1226
# PAPER CHAIN KIT 50'S CHRISTMAS        1200
# JUMBO STORAGE BAG SUKI                1197
# JUMBO SHOPPER VINTAGE RED PAISLEY     1190
# LUNCH BAG SPACEBOY DESIGN             1179
# LUNCH BAG CARS BLUE                   1174
# JAM MAKING SET PRINTED                1169
# SPOTTY BUNTING                        1160
# Name: Description, dtype: int64

# %% [markdown]
# #
# CustomerID
#
# The number of unique customers:

# %%
df['CustomerID'].nunique()
# Out:
# 4340

# %%
df[df['CustomerID'] == '00000'].head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                           Unkown        56
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#              InvoiceDate  UnitPrice CustomerID         Country  Year  Month  \
# 622  2010-12-01 11:52:00       0.00      00000  United Kingdom  2010     12
# 1443 2010-12-01 14:32:00       2.51      00000  United Kingdom  2010     12
# 1444 2010-12-01 14:32:00       2.51      00000  United Kingdom  2010     12
# 1445 2010-12-01 14:32:00       0.85      00000  United Kingdom  2010     12
# 1446 2010-12-01 14:32:00       1.66      00000  United Kingdom  2010     12
#
#       Hour Month_year  Income
# 622     11    2010-12    0.00
# 1443    14    2010-12    2.51
# 1444    14    2010-12    5.02
# 1445    14    2010-12    3.40
# 1446    14    2010-12    3.32

# %% [markdown]
# # The customers who generated the most ordered:

# %%
customer_group = df[['CustomerID', 'InvoiceNo']].groupby('CustomerID').count().sort_values('InvoiceNo', axis=0, ascending=False)
customer_group.head(20)
# Out:
#             InvoiceNo
# CustomerID
# 00000          134697
# 17841.0          7847
# 14911.0          5677
# 14096.0          5111
# 12748.0          4596
# 14606.0          2700
# 15311.0          2379
# 14646.0          2080
# 13089.0          1818
# 13263.0          1677
# 14298.0          1637
# 15039.0          1502
# 14156.0          1400
# 18118.0          1279
# 14159.0          1204
# 14796.0          1141
# 16033.0          1137
# 15005.0          1119
# 14056.0          1106
# 14769.0          1090

# %% [markdown]
# # Analyzing KPIs
#
# We check which country generates the most sales revenues:

# %%
df.groupby('Country')['Income'].sum().sort_values(ascending=False).head(20)
# Out:
# Country
# United Kingdom     9.003098e+06
# Netherlands        2.854463e+05
# EIRE               2.834540e+05
# Germany            2.288671e+05
# France             2.097151e+05
# Australia          1.385213e+05
# Spain              6.157711e+04
# Switzerland        5.708990e+04
# Belgium            4.119634e+04
# Sweden             3.837833e+04
# Japan              3.741637e+04
# Norway             3.616544e+04
# Portugal           3.374710e+04
# Finland            2.254608e+04
# Singapore          2.127929e+04
# Channel Islands    2.045044e+04
# Denmark            1.895534e+04
# Italy              1.748324e+04
# Hong Kong          1.569180e+04
# Cyprus             1.359038e+04
# Name: Income, dtype: float64

# %% [markdown]
# The most revenues comes from UK.
#
# Which products generates the most sales revenues:

# %%
df.groupby('Description')['Income'].sum().sort_values(ascending=False).head(10)
# Out:
# Description
# DOTCOM POSTAGE                        206248.77
# REGENCY CAKESTAND 3 TIER              174484.74
# PAPER CRAFT , LITTLE BIRDIE           168469.60
# WHITE HANGING HEART T-LIGHT HOLDER    106292.77
# PARTY BUNTING                          99504.33
# JUMBO BAG RED RETROSPOT                94340.05
# MEDIUM CERAMIC TOP STORAGE JAR         81700.92
# Manual                                 78112.82
# POSTAGE                                78101.88
# RABBIT NIGHT LIGHT                     66964.99
# Name: Income, dtype: float64

# %% [markdown]
# # Annual Revenue

# %%
df.groupby(['Year'])['Income'].sum()
# Out:
# Year
# 2010    8.237461e+05
# 2011    9.820814e+06
# Name: Income, dtype: float64

# %% [markdown]
# #
# Monthly Revenue
#
# We compile the revenues from month to month:

# %%
df.groupby(['Month_year'])['Income'].sum()
# Out:
# Month_year
# 2010-12     823746.14
# 2011-01     691364.56
# 2011-02     523631.89
# 2011-03     717639.36
# 2011-04     537808.62
# 2011-05     770536.02
# 2011-06     761739.90
# 2011-07     719221.19
# 2011-08     737014.26
# 2011-09    1058590.17
# 2011-10    1154979.30
# 2011-11    1509496.33
# 2011-12     638792.68
# Freq: M, Name: Income, dtype: float64

# %% [markdown]
# # Basket analysis using Apriori algorithm:
#
# The Apriori algorithm is one of the most common techniques in Market Basket Analysis. It is used to analyze the frequent itemsets in a transactional database, which then is used to generate association rules between the products. The association rules exploration is based on the idea that the purchasing behavior of customers follows a pattern that can be used to sell more products to the customer in the future.
# Main Concepts of Association Rules / Apriori Algorithm:
#
# Support is an indication of how frequently the itemset appears in the dataset. This is an indication of how popular an itemset is in a dataset.
#
# Confidence is a measure of the reliability of the rule. Is an indication of how often the rule has been found to be true. It can be said confidence says how likely item Y is purchased when item X is purchased.
#
# Lift shows how likely item Y is purchased when item X is purchased, while controlling for how popular item Y is. In practice means is a lift value close to 1 means the rules were completely independent. Lift values > 1 are generally more “interesting” and could be indicative of a useful rule pattern.
#
# For further analysis, we choose transactions from only one country, we choose Netherlands:

# %%
data = df[df['Country'] == 'Netherlands']
data.head()
# Out:
#       InvoiceNo StockCode                        Description  Quantity  \
# 385      536403     22867            HAND WARMER BIRD DESIGN        96
# 386      536403      POST                            POSTAGE         1
# 37952    539491     21981       PACK OF 12 WOODLAND TISSUES         12
# 37953    539491     21986   PACK OF 12 PINK POLKADOT TISSUES        12
# 37954    539491     22720  SET OF 3 CAKE TINS PANTRY DESIGN          2
#
#               InvoiceDate  UnitPrice CustomerID      Country  Year  Month  \
# 385   2010-12-01 11:27:00       1.85      12791  Netherlands  2010     12
# 386   2010-12-01 11:27:00      15.00      12791  Netherlands  2010     12
# 37952 2010-12-20 10:09:00       0.29      14646  Netherlands  2010     12
# 37953 2010-12-20 10:09:00       0.29      14646  Netherlands  2010     12
# 37954 2010-12-20 10:09:00       4.95      14646  Netherlands  2010     12
#
#        Hour Month_year  Income
# 385      11    2010-12  177.60
# 386      11    2010-12   15.00
# 37952    10    2010-12    3.48
# 37953    10    2010-12    3.48
# 37954    10    2010-12    9.90

# %% [markdown]
# #
# We modify the table with data in such a way that each transaction is written in one line:

# %%
basket = data.groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().fillna(0)
basket
# Out:
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536403                      0.0                           0.0
# 539491                      0.0                           0.0
# 539731                      0.0                           0.0
# 541206                      0.0                           0.0
# 541570                      0.0                           0.0
# ...                         ...                           ...
# 578143                      0.0                           0.0
# 579528                      0.0                           0.0
# 581175                      0.0                           0.0
# 581176                      0.0                           0.0
# 581338                      0.0                           0.0
#
# Description   I LOVE LONDON MINI RUCKSACK   SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536403                                0.0                      0.0
# 539491                                0.0                      0.0
# 539731                                0.0                      0.0
# 541206                                0.0                      0.0
# 541570                                0.0                      0.0
# ...                                   ...                      ...
# 578143                                0.0                      0.0
# 579528                                0.0                      0.0
# 581175                                0.0                      0.0
# 581176                                0.0                      0.0
# 581338                                0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536403                          0.0                            0.0
# 539491                          0.0                            0.0
# 539731                          0.0                            0.0
# 541206                          0.0                            0.0
# 541570                          0.0                            0.0
# ...                             ...                            ...
# 578143                          0.0                          384.0
# 579528                          0.0                            0.0
# 581175                          0.0                            0.0
# 581176                          0.0                            0.0
# 581338                          0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536403                                       0.0
# 539491                                       0.0
# 539731                                       0.0
# 541206                                       0.0
# 541570                                       0.0
# ...                                          ...
# 578143                                       0.0
# 579528                                       0.0
# 581175                                       0.0
# 581176                                       0.0
# 581338                                       0.0
#
# Description  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536403                                      0.0
# 539491                                      0.0
# 539731                                      0.0
# 541206                                      0.0
# 541570                                      0.0
# ...                                         ...
# 578143                                      0.0
# 579528                                      0.0
# 581175                                      0.0
# 581176                                      0.0
# 581338                                      0.0
#
# Description  12 PENCILS TALL TUBE WOODLAND  \
# InvoiceNo
# 536403                                 0.0
# 539491                                 0.0
# 539731                                 0.0
# 541206                                 0.0
# 541570                                 0.0
# ...                                    ...
# 578143                                 0.0
# 579528                                 0.0
# 581175                                 0.0
# 581176                                 0.0
# 581338                                 0.0
#
# Description  16 PIECE CUTLERY SET PANTRY DESIGN  ...  WRAP RED APPLES   \
# InvoiceNo                                        ...
# 536403                                      0.0  ...               0.0
# 539491                                      0.0  ...               0.0
# 539731                                      0.0  ...               0.0
# 541206                                      0.0  ...               0.0
# 541570                                      0.0  ...               0.0
# ...                                         ...  ...               ...
# 578143                                      0.0  ...               0.0
# 579528                                      0.0  ...               0.0
# 581175                                      0.0  ...               0.0
# 581176                                      0.0  ...               0.0
# 581338                                      0.0  ...               0.0
#
# Description  WRAP WEDDING DAY  YELLOW METAL CHICKEN HEART   \
# InvoiceNo
# 536403                    0.0                          0.0
# 539491                    0.0                          0.0
# 539731                    0.0                        192.0
# 541206                    0.0                          0.0
# 541570                    0.0                          0.0
# ...                       ...                          ...
# 578143                    0.0                          0.0
# 579528                    0.0                          0.0
# 581175                    0.0                          0.0
# 581176                    0.0                          0.0
# 581338                    0.0                          0.0
#
# Description  ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER   \
# InvoiceNo
# 536403                              0.0                         0.0
# 539491                              0.0                         0.0
# 539731                              0.0                         0.0
# 541206                              0.0                         0.0
# 541570                              0.0                         0.0
# ...                                 ...                         ...
# 578143                              0.0                         0.0
# 579528                              0.0                         0.0
# 581175                              0.0                         0.0
# 581176                              0.0                         0.0
# 581338                              0.0                         0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536403                             0.0                          0.0
# 539491                             0.0                          0.0
# 539731                             0.0                          0.0
# 541206                             0.0                          0.0
# 541570                             0.0                          0.0
# ...                                ...                          ...
# 578143                             0.0                          0.0
# 579528                             0.0                          0.0
# 581175                             0.0                          0.0
# 581176                             0.0                          0.0
# 581338                             0.0                          0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536403                                  0.0                              0.0
# 539491                                  0.0                              0.0
# 539731                                  0.0                              0.0
# 541206                                  0.0                              0.0
# 541570                                  0.0                              0.0
# ...                                     ...                              ...
# 578143                                  0.0                              0.0
# 579528                                  0.0                              0.0
# 581175                                  0.0                              0.0
# 581176                                  0.0                              0.0
# 581338                                  0.0                              0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536403                                    0.0
# 539491                                    0.0
# 539731                                    0.0
# 541206                                    0.0
# 541570                                    0.0
# ...                                       ...
# 578143                                    0.0
# 579528                                    0.0
# 581175                                    0.0
# 581176                                    0.0
# 581338                                    0.0
#
# [95 rows x 803 columns]

# %% [markdown]
# #
# Next we modify the table in such a way that the presence of a product in the basket means '1', and the lack of a product means '0':

# %%
basket_model = basket.applymap(lambda x: 1 if x>0 else 0)
basket_model
# Out:
# Description   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# InvoiceNo
# 536403                        0                             0
# 539491                        0                             0
# 539731                        0                             0
# 541206                        0                             0
# 541570                        0                             0
# ...                         ...                           ...
# 578143                        0                             0
# 579528                        0                             0
# 581175                        0                             0
# 581176                        0                             0
# 581338                        0                             0
#
# Description   I LOVE LONDON MINI RUCKSACK   SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536403                                  0                        0
# 539491                                  0                        0
# 539731                                  0                        0
# 541206                                  0                        0
# 541570                                  0                        0
# ...                                   ...                      ...
# 578143                                  0                        0
# 579528                                  0                        0
# 581175                                  0                        0
# 581176                                  0                        0
# 581338                                  0                        0
#
# Description  10 COLOUR SPACEBOY PEN  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536403                            0                              0
# 539491                            0                              0
# 539731                            0                              0
# 541206                            0                              0
# 541570                            0                              0
# ...                             ...                            ...
# 578143                            0                              1
# 579528                            0                              0
# 581175                            0                              0
# 581176                            0                              0
# 581338                            0                              0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536403                                         0
# 539491                                         0
# 539731                                         0
# 541206                                         0
# 541570                                         0
# ...                                          ...
# 578143                                         0
# 579528                                         0
# 581175                                         0
# 581176                                         0
# 581338                                         0
#
# Description  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536403                                        0
# 539491                                        0
# 539731                                        0
# 541206                                        0
# 541570                                        0
# ...                                         ...
# 578143                                        0
# 579528                                        0
# 581175                                        0
# 581176                                        0
# 581338                                        0
#
# Description  12 PENCILS TALL TUBE WOODLAND  \
# InvoiceNo
# 536403                                   0
# 539491                                   0
# 539731                                   0
# 541206                                   0
# 541570                                   0
# ...                                    ...
# 578143                                   0
# 579528                                   0
# 581175                                   0
# 581176                                   0
# 581338                                   0
#
# Description  16 PIECE CUTLERY SET PANTRY DESIGN  ...  WRAP RED APPLES   \
# InvoiceNo                                        ...
# 536403                                        0  ...                 0
# 539491                                        0  ...                 0
# 539731                                        0  ...                 0
# 541206                                        0  ...                 0
# 541570                                        0  ...                 0
# ...                                         ...  ...               ...
# 578143                                        0  ...                 0
# 579528                                        0  ...                 0
# 581175                                        0  ...                 0
# 581176                                        0  ...                 0
# 581338                                        0  ...                 0
#
# Description  WRAP WEDDING DAY  YELLOW METAL CHICKEN HEART   \
# InvoiceNo
# 536403                      0                            0
# 539491                      0                            0
# 539731                      0                            1
# 541206                      0                            0
# 541570                      0                            0
# ...                       ...                          ...
# 578143                      0                            0
# 579528                      0                            0
# 581175                      0                            0
# 581176                      0                            0
# 581338                      0                            0
#
# Description  ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER   \
# InvoiceNo
# 536403                                0                           0
# 539491                                0                           0
# 539731                                0                           0
# 541206                                0                           0
# 541570                                0                           0
# ...                                 ...                         ...
# 578143                                0                           0
# 579528                                0                           0
# 581175                                0                           0
# 581176                                0                           0
# 581338                                0                           0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536403                               0                            0
# 539491                               0                            0
# 539731                               0                            0
# 541206                               0                            0
# 541570                               0                            0
# ...                                ...                          ...
# 578143                               0                            0
# 579528                               0                            0
# 581175                               0                            0
# 581176                               0                            0
# 581338                               0                            0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536403                                    0                                0
# 539491                                    0                                0
# 539731                                    0                                0
# 541206                                    0                                0
# 541570                                    0                                0
# ...                                     ...                              ...
# 578143                                    0                                0
# 579528                                    0                                0
# 581175                                    0                                0
# 581176                                    0                                0
# 581338                                    0                                0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536403                                      0
# 539491                                      0
# 539731                                      0
# 541206                                      0
# 541570                                      0
# ...                                       ...
# 578143                                      0
# 579528                                      0
# 581175                                      0
# 581176                                      0
# 581338                                      0
#
# [95 rows x 803 columns]

# %% [markdown]
# # In this case we set 'min_support' on 0,08

# %%
popular_sets = apriori(basket_model, min_support=0.08, use_colnames=True)

# %%
popular_sets
# Out:
#       support                                           itemsets
# 0    0.105263                   (72 SWEETHEART FAIRY CAKE CASES)
# 1    0.094737                             (CARD BIRTHDAY COWBOY)
# 2    0.126316                                 (CARD DOLLY GIRL )
# 3    0.094737                               (CARD GINGHAM ROSE )
# 4    0.084211                      (CHARLOTTE BAG APPLES DESIGN)
# ..        ...                                                ...
# 199  0.084211  (DOLLY GIRL LUNCH BOX, SPACEBOY BIRTHDAY CARD,...
# 200  0.084211  (DOLLY GIRL LUNCH BOX, ROUND SNACK BOXES SET O...
# 201  0.084211  (DOLLY GIRL LUNCH BOX, ROUND SNACK BOXES SET O...
# 202  0.084211  (DOLLY GIRL LUNCH BOX, STRAWBERRY LUNCH BOX WI...
# 203  0.084211  (SPACEBOY BIRTHDAY CARD, ROUND SNACK BOXES SET...
#
# [204 rows x 2 columns]

# %%
rules = association_rules(popular_sets,metric='lift',min_threshold=1)

# %%
rules.head(10)
# Out:
#                              antecedents  \
# 0                 (DOLLY GIRL LUNCH BOX)
# 1       (72 SWEETHEART FAIRY CAKE CASES)
# 2       (72 SWEETHEART FAIRY CAKE CASES)
# 3                  (SPACEBOY LUNCH BOX )
# 4               (SPACEBOY BIRTHDAY CARD)
# 5                 (CARD BIRTHDAY COWBOY)
# 6                  (SPACEBOY LUNCH BOX )
# 7                 (CARD BIRTHDAY COWBOY)
# 8  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 9                     (CARD DOLLY GIRL )
#
#                              consequents  antecedent support  \
# 0       (72 SWEETHEART FAIRY CAKE CASES)            0.231579
# 1                 (DOLLY GIRL LUNCH BOX)            0.105263
# 2                  (SPACEBOY LUNCH BOX )            0.105263
# 3       (72 SWEETHEART FAIRY CAKE CASES)            0.294737
# 4                 (CARD BIRTHDAY COWBOY)            0.178947
# 5               (SPACEBOY BIRTHDAY CARD)            0.094737
# 6                 (CARD BIRTHDAY COWBOY)            0.294737
# 7                  (SPACEBOY LUNCH BOX )            0.094737
# 8                     (CARD DOLLY GIRL )            0.263158
# 9  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.126316
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.105263  0.094737    0.409091  3.886364  0.070360    1.514170
# 1            0.231579  0.094737    0.900000  3.886364  0.070360    7.684211
# 2            0.294737  0.094737    0.900000  3.053571  0.063712    7.052632
# 3            0.105263  0.094737    0.321429  3.053571  0.063712    1.318560
# 4            0.094737  0.084211    0.470588  4.967320  0.067258    1.709942
# 5            0.178947  0.084211    0.888889  4.967320  0.067258    7.389474
# 6            0.094737  0.084211    0.285714  3.015873  0.056288    1.267368
# 7            0.294737  0.084211    0.888889  3.015873  0.056288    6.347368
# 8            0.126316  0.094737    0.360000  2.850000  0.061496    1.365132
# 9            0.263158  0.094737    0.750000  2.850000  0.061496    2.947368

# %% [markdown]
# #
# We can see that there are quite a few rules with a high lift value which means that it occurs more frequently. We can also see several where the confidence is high as well. Now we filter the dataframe for loking a large lift (5) and high confidence (1):

# %%
rules[ (rules['lift'] >= 5) &
       (rules['confidence'] >= 1) ]
# Out:
#                                            antecedents  \
# 108                   (PACK OF 60 MUSHROOM CAKE CASES)
# 331  (SPACEBOY BIRTHDAY CARD, LUNCH BAG RED RETROSPOT)
# 332  (PLASTERS IN TIN SPACEBOY, LUNCH BAG RED RETRO...
# 473   (DOLLY GIRL LUNCH BOX, PLASTERS IN TIN SPACEBOY)
# 486  (DOLLY GIRL LUNCH BOX, RED RETROSPOT CHARLOTTE...
# 490  (RED RETROSPOT CHARLOTTE BAG, SPACEBOY LUNCH B...
# 514     (DOLLY GIRL LUNCH BOX, SPACEBOY BIRTHDAY CARD)
# 567  (SPACEBOY BIRTHDAY CARD, ROUND SNACK BOXES SET...
# 569  (ROUND SNACK BOXES SET OF4 WOODLAND , PLASTERS...
# 572  (SPACEBOY BIRTHDAY CARD, LUNCH BAG RED RETROSPOT)
# 575  (PLASTERS IN TIN SPACEBOY, LUNCH BAG RED RETRO...
#
#                                            consequents  antecedent support  \
# 108                           (SPACEBOY BIRTHDAY CARD)            0.084211
# 331                         (PLASTERS IN TIN SPACEBOY)            0.084211
# 332                           (SPACEBOY BIRTHDAY CARD)            0.084211
# 473  (ROUND SNACK BOXES SET OF4 WOODLAND , SPACEBOY...            0.084211
# 486  (ROUND SNACK BOXES SET OF4 WOODLAND , SPACEBOY...            0.094737
# 490  (DOLLY GIRL LUNCH BOX, ROUND SNACK BOXES SET O...            0.094737
# 514  (ROUND SNACK BOXES SET OF4 WOODLAND , SPACEBOY...            0.084211
# 567                         (PLASTERS IN TIN SPACEBOY)            0.084211
# 569                           (SPACEBOY BIRTHDAY CARD)            0.084211
# 572  (ROUND SNACK BOXES SET OF4 WOODLAND , PLASTERS...            0.084211
# 575  (SPACEBOY BIRTHDAY CARD, ROUND SNACK BOXES SET...            0.084211
#
#      consequent support   support  confidence      lift  leverage  conviction
# 108            0.178947  0.084211         1.0  5.588235  0.069141         inf
# 331            0.126316  0.084211         1.0  7.916667  0.073573         inf
# 332            0.178947  0.084211         1.0  5.588235  0.069141         inf
# 473            0.189474  0.084211         1.0  5.277778  0.068255         inf
# 486            0.189474  0.094737         1.0  5.277778  0.076787         inf
# 490            0.168421  0.094737         1.0  5.937500  0.078781         inf
# 514            0.189474  0.084211         1.0  5.277778  0.068255         inf
# 567            0.126316  0.084211         1.0  7.916667  0.073573         inf
# 569            0.178947  0.084211         1.0  5.588235  0.069141         inf
# 572            0.126316  0.084211         1.0  7.916667  0.073573         inf
# 575            0.136842  0.084211         1.0  7.307692  0.072687         inf

# %% [markdown]
# #
# For received results we can see that for example SPACEBOY BIRTHDAY CARD with ROUND SNACK BOXES and PLASTERS IN TIN SPACEBOY are bought together, and SPACEBOY BIRTHDAY CARD with LUNCH BAG RED RETROSPOT are also bought with PLASTERS IN TIN SPACEBOY.

# %% [markdown]
# # Recommendations

# %%
rules['antecedents'][332]
# Out:
# frozenset({'LUNCH BAG RED RETROSPOT', 'PLASTERS IN TIN SPACEBOY'})

# %%
basket_model['PLASTERS IN TIN SPACEBOY'].sum()
# Out:
# 12

# %%
basket_model['LUNCH BAG RED RETROSPOT'].sum()
# Out:
# 10

# %%
basket_model['SPACEBOY BIRTHDAY CARD'].sum()
# Out:
# 17

# %% [markdown]
# # At this point, you can see how great the possibilities are to use the popularity of one product to increase the sales of another. For example we see that 17 SPACEBOY BIRTHDAY CARD have been sold, but only sold 12 PLASTERS IN TIN SPACEBOY. So if we compare one item with another, it may allow for increasing the sale of the other one. And through this it will be possible to increase sales, for example, PLASTERS IN TIN SPACEBOY.
